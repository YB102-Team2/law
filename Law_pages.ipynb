# %%
import requests
from bs4 import BeautifulSoup
import re
payload = {
'nccharset':'612DBD49',
'v_court':'TPD 臺灣臺北地方法院',
'v_sys':'M',
'jud_year':'',
'sel_judword':'常用字別',
'jud_case':'',
'jud_no':'',
'jt':'',
'dy1':'80',
'dm1':'1',
'dd1':'1',
'dy2':'104',
'dm2':'1',
'dd2':'1',
'kw':'',
'keyword':'',
'sdate':'19910101',
'edate':'20150101',
'jud_title':'',
'Button':'查詢',
'searchkw':''
}

header = {
'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY01_1.aspx',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
}

rs = requests.Session()
rs_post = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx', data=payload, headers=header)
soup = BeautifulSoup(rs_post.text)
print soup

link = soup.select('a')
big = soup.select('.big')[1]
# print big.text
linkLst = []
for item in link:
    linkLst.append('http://jirs.judicial.gov.tw/FJUD/' + str(item)[9:-30])
    
print linkLst[0]
print link[0]
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-83-982e1574b50d> in <module>()
#      32
#      33 rs = requests.Session()
# ---> 34 rs_post = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx', data=payload, headers=header)
#      35 soup = BeautifulSoup(rs_post.text)
#      36 print soup
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in post(self, url, data, json, **kwargs)
#     502         """
#     503
# --> 504         return self.request('POST', url, data=data, json=json, **kwargs)
#     505
#     506     def put(self, url, data=None, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459         }
#     460         send_kwargs.update(settings)
# --> 461         resp = self.send(prep, **send_kwargs)
#     462
#     463         return resp
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     413
#     414         except (ProtocolError, socket.error) as err:
# --> 415             raise ConnectionError(err, request=request)
#     416
#     417         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', error(60, 'Operation timed out'))

# %%
header = {
'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=1&searchkw=',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
}

rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=2&searchkw=', headers=header)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-77-a556f24d244b> in <module>()
#       4 }
#       5
# ----> 6 rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=2&searchkw=', headers=header)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     471
#     472         kwargs.setdefault('allow_redirects', True)
# --> 473         return self.request('GET', url, **kwargs)
#     474
#     475     def options(self, url, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459         }
#     460         send_kwargs.update(settings)
# --> 461         resp = self.send(prep, **send_kwargs)
#     462
#     463         return resp
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     413
#     414         except (ProtocolError, socket.error) as err:
# --> 415             raise ConnectionError(err, request=request)
#     416
#     417         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', gaierror(8, 'nodename nor servname provided, or not known'))

# %%
soup = BeautifulSoup(rs_get.text)
case_link = []
for tag in soup.find_all('a'):
    tag = str(tag)[9:-18]
    case_link.append('http://jirs.judicial.gov.tw/FJUD/' + tag)
case_link = case_link[5:-6]    
# for item in case_link:
#    print item
header = {
'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=4&searchkw=',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
}

rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=2&searchkw=', headers=header)

soup = BeautifulSoup(rs_get.text)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-78-c5bdd9cd0348> in <module>()
#      12 }
#      13
# ---> 14 rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=2&searchkw=', headers=header)
#      15
#      16 soup = BeautifulSoup(rs_get.text)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     471
#     472         kwargs.setdefault('allow_redirects', True)
# --> 473         return self.request('GET', url, **kwargs)
#     474
#     475     def options(self, url, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459         }
#     460         send_kwargs.update(settings)
# --> 461         resp = self.send(prep, **send_kwargs)
#     462
#     463         return resp
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     413
#     414         except (ProtocolError, socket.error) as err:
# --> 415             raise ConnectionError(err, request=request)
#     416
#     417         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', gaierror(8, 'nodename nor servname provided, or not known'))

# %%
header = {
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=1&searchkw='
}
rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=4&searchkw=', headers=header)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-79-33c4bee38436> in <module>()
#       3 'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=1&searchkw='
#       4 }
# ----> 5 rs_get = rs.get('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=&sdate=19910101&edate=20150101&page=4&searchkw=', headers=header)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in get(self, url, **kwargs)
#     471
#     472         kwargs.setdefault('allow_redirects', True)
# --> 473         return self.request('GET', url, **kwargs)
#     474
#     475     def options(self, url, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459         }
#     460         send_kwargs.update(settings)
# --> 461         resp = self.send(prep, **send_kwargs)
#     462
#     463         return resp
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     413
#     414         except (ProtocolError, socket.error) as err:
# --> 415             raise ConnectionError(err, request=request)
#     416
#     417         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', gaierror(8, 'nodename nor servname provided, or not known'))

# %%
soup = BeautifulSoup(rs_get.text)
print soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
# <head>
# <title>裁判書查詢</title>
# <meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR"/>
# <meta content="C#" name="CODE_LANGUAGE"/>
# <meta content="JavaScript" name="vs_defaultClientScript"/>
# <meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="本網站通過第一、第二及第三優先等級無障礙網頁檢測" name="AAAccessible_website"/>
# <script language="JavaScript" src="Js/Fyls.js"></script>
# <noscript>
# </noscript></head>
# <body bgcolor="#ffffff" leftmargin="0" topmargin="0">
# 		您的瀏覽器不支援JavaScript語法,但是並不影響您獲取本網站的內容
# 		<script language="JavaScript">
# function openwin(URL,arguments,width,height)
# {
#    //功能:開一個非獨佔的視窗
#    //參數1.URL :連結的網頁
#    //參數2.arguments :傳入網頁的參數
#    /*
#    var str = URL  //+"?"+arguments;
#    newWindow=top.open("","","maximize=no,toolbar=no,directories=no,status=yes,scrollbars=yes,hscrollbars=no,menubar=no");
#
#    if(width==null&&height==null)
#    {
#      width=screen.width;
#      height=screen.availHeight;
#
#    }
#    if ((width!=null)&&(height!=null))
#       newWindow.resizeTo(width,height);
#    else
#       newWindow.resizeTo(screen.width,screen.availHeight);
#    newWindow.moveTo((screen.width-width)/2,(screen.availHeight-height)/2);
#    newWindow.location=str;
#    */
#    if((width==null&&height==null) || (width==''&&height==''))
#    {
# 		width=screen.width;
# 		height=screen.availHeight;
#    }
#    pars = "width="+width+",height="+height+",maximize=no,toolbar=no,directories=no,status=yes,scrollbars=yes,hscrollbars=no,resize=no,menubar=no";
#    newWindow=top.open(URL,"",pars);
#    newWindow.moveTo((screen.width-width)/2,(screen.availHeight-height)/2);
# }
#
# 		</script>
# <noscript>
# 			您的瀏覽器不支援JavaScript語法,但是並不影響您獲取本網站的內容</noscript>
# <form action="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=" id="Form1" method="get" name="Form1"><input name="nccharset" type="hidden" value="8C9A436B"/>
# <input name="__VIEWSTATE" type="hidden" value="dDwtMjc3OTk4NTc5Ozs+9RYjq2AJ3TsCPqFgd/QB+uRu4LQ="/>
# <table border="0" cellpadding="0" cellspacing="0" style="WIDTH:760px" summary="排版用表格">
# <tr>
# <td> </td>
# </tr>
# </table>
# <table align="center" border="0" cellpadding="3" summary="排版用表格" width="89%">
# <tr>
# <td colspan="2">
# <div align="center"><strong><big> <span style="FONT-SIZE: 80%">
# 										臺灣臺北地方法院 裁判書 -- 刑事類
# 									</span></big></strong>
# </div>
# </td>
# </tr>
# </table>
# <!-- 上方分頁 -->
# <table align="center" border="0" cellpadding="0" cellspacing="0" style="WIDTH:760px" summary="排版用表格">
# <tr>
# <td background="Images_1/fjudqry01title.gif" style="HEIGHT: 33px">
# <table border="0" cellpadding="0" cellspacing="0" class="big" summary="排版用表格" width="338">
# <tr>
# <td>
# <div align="right"><span style="FONT-SIZE: 80%">有加底線者為可點選之項目</span></div>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <table align="center" border="0" cellpadding="0" cellspacing="0" style="WIDTH:760px" summary="排版用表格">
# <tr>
# <td align="center" background="Images_1/fjudqry01table02.gif">
# <div align="center">
# <table align="center" border="0" cellpadding="0" cellspacing="0" style="WIDTH:750px" summary="排版用表格">
# <tr><td align="center" colspan="2" valign="middle" width="42%">本次查詢結果共232515筆，超出 200 筆，只顯示前 200 筆</td></tr>
# <tr>
# <td align="center" valign="middle" width="42%"><font size="2"> 共
# 											200
# 											筆 / 每頁
# 											20
# 											筆 / 共
# 											10
# 											頁 / 現在第
# 											2
# 											頁</font></td>
# <td valign="middle" width="58%">
# <div align="right">
# <font size="2"><a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=1&amp;searchkw=">第一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=1&amp;searchkw=">上一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=3&amp;searchkw=">下一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=10&amp;searchkw=">最末頁</a></font>
# <font size="2">跳至<select id="ddlPage" name="ddlPage" onchange="selectPage(this.selectedIndex+1)">
# <option value="1">1</option>
# <option selected="selected" value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# </select>頁  </font>
# </div>
# </td>
# </tr>
# </table>
# <table align="center" border="1" bordercolor="#e9e3d1" cellpadding="3" cellspacing="0" class="big" id="Table3" width="735">
# <tbody>
# <tr>
# <th align="center" height="25" width="8%">
# <span style="font-size: 80%; color:#990000"><strong>序號</strong></span>
# </th>
# <th align="left" height="25" width="22%">
# <span style="font-size: 80%; color:#990000"><strong>裁判字號(檔案大小)</strong></span>
# </th>
# <th align="left" height="25" width="15%">
# <span style="font-size: 80%; color:#990000"><strong>裁判日期</strong></span>
# </th>
# <th align="left" height="25" width="33%">
# <span style="font-size: 80%; color:#990000"><strong>裁判案由</strong></span>
# </th>
# </tr>
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">21</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=21&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,聲,3080</a> (4K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">聲請單獨宣告沒收扣押物</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">22</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=22&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,聲,3258</a> (1K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">聲請假釋中付保護管束</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">23</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=23&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,聲,3264</a> (5K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">聲請定應執行刑並諭知易科罰金折算標準</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">24</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=24&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,簡,3475</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">毒品危害防制條例</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">25</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=25&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,簡,3503</a> (5K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">毒品危害防制條例</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">26</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=26&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,簡,3558</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">妨害名譽</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">27</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=27&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,簡,3581</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">毒品危害防制條例</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">28</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=28&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">102,金重易,7</a> (137K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">背信</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">29</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=29&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,審訴,880</a> (10K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">妨害風化</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">30</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=30&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,審簡,1933</a> (7K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">毒品危害防制條例</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">31</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=31&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,4018</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">32</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=32&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,3377</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">33</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=33&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,3542</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">34</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=34&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,3951</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">35</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=35&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,3999</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">36</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=36&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,4012</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">37</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=37&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,4014</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">38</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=38&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,4037</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">39</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=39&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,交簡,4042</a> (3K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">公共危險</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# <tr bgcolor="#FFFFFF">
# <!-- 序號 -->
# <td height="25" width="8%">
# <div align="center"><font size="2">40</font></div>
# </td>
# <!-- 裁判字號 -->
# <td height="25" width="22%">
# <div align="left"><font size="2"><a href="FJUDQRY03_1.aspx?id=40&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=2&amp;searchkw=">103,易,1265</a> (2K)</font></div>
# </td>
# <!-- 日期及案由 -->
# <td height="25" width="15%">
# <div align="left"><font size="2">1031231</font></div>
# </td>
# <td height="25" width="23%">
# <div align="left"><font size="2">傷害</font></div>
# </td>
# </tr>
# <!-- 不可公開或太早 -->
# </tbody>
# </table>
# <table align="center" border="0" cellpadding="0" cellspacing="0" style="WIDTH:750px" summary="排版用表格">
# <tr>
# <td align="center" valign="middle" width="42%"><font size="2"> 共
# 											200
# 											筆 / 每頁
# 											20
# 											筆 / 共
# 											10
# 											頁 / 現在第
# 											2
# 											頁</font></td>
# <td valign="middle" width="58%">
# <div align="right">
# <font size="2"><a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=1&amp;searchkw=">第一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=1&amp;searchkw=">上一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=3&amp;searchkw=">下一頁</a>｜<a href="FJUDQRY02_1.aspx?&amp;v_court=TPD+%e8%87%ba%e7%81%a3%e8%87%ba%e5%8c%97%e5%9c%b0%e6%96%b9%e6%b3%95%e9%99%a2&amp;v_sys=M&amp;jud_year=&amp;jud_case=&amp;jud_no=&amp;jud_title=&amp;keyword=&amp;sdate=19910101&amp;edate=20150101&amp;page=10&amp;searchkw=">最末頁</a></font>
# <font size="2">跳至<select id="ddlPage2" name="ddlPage2" onchange="selectPage(this.selectedIndex+1)">
# <option value="1">1</option>
# <option selected="selected" value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# </select>頁  </font>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </td>
# </tr>
# <tr>
# <td style="HEIGHT: 10px"><img alt="排版圖示" src="Images_1/fjudqry01table03.gif"/></td>
# </tr>
# </table>
# <script language="JavaScript">
# <!--
#
#
#
# function MM_preloadImages_1() { //v3.0
#   var d=document; if(d.Images_1){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages_1.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
# //-->
# 			</script>
# <noscript>
# 				您的瀏覽器不支援JavaScript語法,但是並不影響您獲取本網站的內容</noscript>
# <table align="center" border="0" cellpadding="0" cellspacing="0" style="WIDTH:760px; HEIGHT:33px" summary="排版用表格">
# <tr>
# <td background="Images_1/welcome.gif"><table border="0" cellpadding="0" cellspacing="0" summary="排版用表格" width="100%">
# <tr>
# <td width="12%"> </td>
# <td width="75%"><div align="center"><span style="FONT-SIZE: 80%"><a href="http://www.judicial.gov.tw" target="_parent">司法院</a>
# 											資訊管理處 製作。 對於本系統功能有任何建議，<a href="http://www.judicial.gov.tw/email/write.htm" target="_blank">
# 												歡迎來信</a></span>。</div>
# </td>
# <td width="13%"> </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <input name="id" type="hidden" value=""/> <input name="v_court" type="hidden" value="TPD 臺灣臺北地方法院"/>
# <input name="v_sys" type="hidden" value="M"/> <input name="jud_year" type="hidden" value=""/>
# <input name="jud_case" type="hidden" value=""/> <input name="jud_no" type="hidden" value=""/>
# <input name="jud_title" type="hidden" value=""/> <input name="keyword" type="hidden" value=""/>
# <input name="sdate" type="hidden" value="19910101"/> <input name="edate" type="hidden" value="20150101"/>
# <input name="page" type="hidden" value="2"/> <input name="searchkw" type="hidden" value=""/>
# </form>
# <form action="transfer.aspx" id="Form3" method="get" name="Form3"><input name="nccharset" type="hidden" value="8C9A436B"/>
# <input name="LAWUNIT" type="hidden"/> <input name="CASEYEAR" type="hidden"/> <input name="CASEFIELD" type="hidden"/>
# <input name="CASENO" type="hidden"/> <input name="CASETYPE" type="hidden"/>
# </form>
# <script language="javascript">
# 	function selectPage(page){
# 		document.Form1.page.value = page;
# 		document.Form1.submit();
# 	}
# 		</script>
# <script language="javascript">
# function sendemail(sUnit,sYear,sCASE,sNO,sType){
# 	document.Form3.LAWUNIT.value=sUnit;
# 	document.Form3.CASEYEAR.value=sYear;
# 	document.Form3.CASEFIELD.value=sCASE;
# 	document.Form3.CASENO.value=sNO;
# 	document.Form3.CASETYPE.value=sType;
# 	document.Form3.submit();
# }
# function openNoData(){
# 	window.open('nodata.aspx','說明','scrollbars=1,resizable=1,width=680,height=270,left=' + (screen.width-650)/2 + ',top=' + (screen.height-270)/2);
# }
# 		</script>
# </body>
# </html>
