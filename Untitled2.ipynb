# %%
# -*- coding: utf-8 -*- 
import requests
from bs4 import BeautifulSoup 

rs = requests.session()
payload ={
'nccharset':'612DA531',
'v_court':'IPC 智慧財產法院',
'v_sys':'V',
'jud_year':'',
'sel_judword':'常用字別',
'jud_case':'',
'jud_no':'',
'jt':'',
'dy1':'',
'dm1':'',
'dd1':'',
'dy2':'',
'dm2':'',
'dd2':'',
'kw':'侵權',
'keyword':'侵權',
'sdate':'',
'edate':'',
'jud_title':'',
'Button':'查詢',
'searchkw':'侵權'
}

header = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

header2 = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=1&searchkw=%e4%be%b5%e6%ac%8a',
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

header3 = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

r1 = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx', data=payload, headers=header)

r2 = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=V&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=2&searchkw=%e4%be%b5%e6%ac%8a', data=payload, headers=header2)

rt = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY03_1.aspx?id=1&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=V&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=&searchkw=%e4%be%b5%e6%ac%8a', data=payload, headers=header3)



#response_text = rt.text.encode('utf8') 

response_text = r1.text 

soup = BeautifulSoup(response_text)

print soup.text

tr = soup.select("tr")

#for tr in tr[4:9]:
#    x = tr.select("td")
#    for td in x:
#        print td.text.strip(),
#    print
#print



#bid_file = open("bid_list.txt", 'w') 


#bid_file.close()
# Out:
# 裁判書查詢
#
#
#
#
#
#
#
#
#
#
# 		您的瀏覽器不支援JavaScript語法,但是並不影響您獲取本網站的內容
#
# function openwin(URL,arguments,width,height)
# {
#    //功能:開一個非獨佔的視窗
#    //參數1.URL :連結的網頁
#    //參數2.arguments :傳入網頁的參數
#    /*
#    var str = URL  //+"?"+arguments;
#    newWindow=top.open("","","maximize=no,toolbar=no,directories=no,status=yes,scrollbars=yes,hscrollbars=no,menubar=no");
#
#    if(width==null&&height==null)
#    {
#      width=screen.width;
#      height=screen.availHeight;
#
#    }
#    if ((width!=null)&&(height!=null))
#       newWindow.resizeTo(width,height);
#    else
#       newWindow.resizeTo(screen.width,screen.availHeight);
#    newWindow.moveTo((screen.width-width)/2,(screen.availHeight-height)/2);
#    newWindow.location=str;
#    */
#    if((width==null&&height==null) || (width==''&&height==''))
#    {
# 		width=screen.width;
# 		height=screen.availHeight;
#    }
# ...

# %%
# -*- coding: utf-8 -*- 
import requests
from bs4 import BeautifulSoup 

rs = requests.session()
payload ={
'nccharset':'612DA531',
'v_court':'IPC 智慧財產法院',
'v_sys':'V',
'jud_year':'',
'sel_judword':'常用字別',
'jud_case':'',
'jud_no':'',
'jt':'',
'dy1':'',
'dm1':'',
'dd1':'',
'dy2':'',
'dm2':'',
'dd2':'',
'kw':'侵權',
'keyword':'侵權',
'sdate':'',
'edate':'',
'jud_title':'',
'Button':'查詢',
'searchkw':'侵權'
}

header = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

header2 = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=M&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=1&searchkw=%e4%be%b5%e6%ac%8a',
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

header3 = {

'Referer':'http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx',
'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

}

r1 = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx', data=payload, headers=header)

r2 = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY02_1.aspx?&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=V&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=2&searchkw=%e4%be%b5%e6%ac%8a', data=payload, headers=header2)

rt = rs.post('http://jirs.judicial.gov.tw/FJUD/FJUDQRY03_1.aspx?id=1&v_court=IPC+%e6%99%ba%e6%85%a7%e8%b2%a1%e7%94%a2%e6%b3%95%e9%99%a2&v_sys=V&jud_year=&jud_case=&jud_no=&jud_title=&keyword=%e4%be%b5%e6%ac%8a&sdate=&edate=&page=&searchkw=%e4%be%b5%e6%ac%8a', data=payload, headers=header3)



#response_text = rt.text.encode('utf8') 

response_text = r1.text 

soup = BeautifulSoup(response_text)

#print soup.text

tr = soup.select("tr")


for tr in tr[8:28]:
    x = tr.select("td")[1].text.strip()
#    for td in x:
#        print td.text.strip(),
    print x.split(" ")[0]
#print



#bid_file = open("bid_list.txt", 'w') 


#bid_file.close()
# Out:
# 102,民商訴,19
# 103,民著訴,5
# 103,民商上,4
# 103,民專上,10
# 103,民專上,15
# 103,民專上,25
# 102,民商上,14
# 103,民專訴,49
# 103,民著訴,57
# 103,民著訴,60
# 103,民專訴,36
# 103,民著上易,7
# 103,民專上,13
# 103,民著訴,10
# 102,民著訴,62
# 103,民著上,11
# 103,民商訴,7
# 103,民專訴,17
# 103,民著訴,25
# 103,民商訴,26
